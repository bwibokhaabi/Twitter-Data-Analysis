# %%
from extract_dataframe_test import TweetDfExtractor

# %%
import json
import pandas as pd
from textblob import TextBlob

def read_json(json_file: str)->list:
   
    tweets_data = []
    for tweets in open(json_file,'r'):
        tweets_data.append(json.loads(tweets))
    
    
    return len(tweets_data), tweets_data

# %%
test_tweet_num ,test_tweet_list = read_json("merged-ke-ng-sa.json")
tweet = TweetDfExtractor(test_tweet_list)
test_tweet_df = tweet.get_tweet_df()

# %%
 tweet = TweetDfExtractor(test_tweet_list)

# %%
 test_tweet_df = tweet.get_tweet_df()
# Out:
# File Successfully Saved.!!!

# %%
import warnings
warnings.filterwarnings('ignore')
from clean_tweets_dataframe import Clean_Tweets
import pandas as pd

# %%
train_df=pd.read_csv('processed_tweet_data.csv')
test_df=pd.read_csv('test_processed_tweet_data.csv')

# %%
#A class oject called cleaner is initialized to clean the dataset
cleaner = Clean_Tweets(df)
# Out:
# Automation in Action...!!!

# %%
cleaned_data_train= cleaner.clean_df(train_df)

# %%
cleaned_data_test= cleaner.clean_df(test_df)

# %%
cleaned_data_train.shape
# Out:
# (16472, 14)

# %% [markdown]
# The dataset has 14 columns and 16,472 rows

# %%
cleaned_data_test.shape
# Out:
# (75961, 14)

# %% [markdown]
# The dataset has 14 columns and 75,961 rows

# %%
cleaned_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16472 entries, 38 to 24622
# Data columns (total 14 columns):
# created_at         16472 non-null datetime64[ns, UTC]
# source             16472 non-null object
# original_text      16472 non-null object
# polarity           16472 non-null float64
# subjectivity       16472 non-null float64
# lang               16472 non-null object
# favorite_count     16472 non-null int64
# retweet_count      16472 non-null int64
# original_author    16472 non-null object
# followers_count    16472 non-null int64
# friends_count      16472 non-null int64
# hashtags           16472 non-null object
# user_mentions      16472 non-null object
# place              5941 non-null object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(4), object(7)
# memory usage: 1.9+ MB

# %%
cleaned_data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75961 entries, 0 to 92547
# Data columns (total 14 columns):
# created_at         75961 non-null datetime64[ns, UTC]
# source             75961 non-null object
# original_text      75961 non-null object
# polarity           75961 non-null float64
# subjectivity       75961 non-null float64
# lang               75961 non-null object
# favorite_count     75961 non-null int64
# retweet_count      75961 non-null int64
# original_author    75961 non-null object
# followers_count    75961 non-null int64
# friends_count      75961 non-null int64
# hashtags           75961 non-null object
# user_mentions      75961 non-null object
# place              17936 non-null object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(4), object(7)
# memory usage: 8.7+ MB

# %% [markdown]
# The dataset has four distimct data types:data,time ,int,float and object

# %%
cleaned_data_train.head()
# Out:
#                   created_at  \
# 38 2022-04-22 22:17:05+00:00
# 39 2022-04-22 13:44:53+00:00
# 41 2022-04-22 06:10:34+00:00
# 42 2022-04-21 17:22:09+00:00
# 43 2022-04-21 10:32:26+00:00
#
#                                                source  \
# 38  <a href="http://twitter.com/download/android" ...
# 39  <a href="http://twitter.com/download/android" ...
# 41  <a href="http://twitter.com/download/android" ...
# 42  <a href="http://twitter.com/download/android" ...
# 43  <a href="http://twitter.com/download/android" ...
#
#                                         original_text  polarity  subjectivity  \
# 38  RT @NorthstarCharts: The 10-year yield is tell...      0.16      0.540000
# 39  RT @MichaelAArouet: German 10y mortgage rate w...      0.15      0.175000
# 41        RT @goldseek: When? https://t.co/kO2FfHKaZg      0.00      0.000000
# 42  RT @charliebilello: The 30-year mortgage rate ...      0.00      0.183333
# 43  RT @biancoresearch: Rates rise until something...     -0.40      0.400000
#
#    lang  favorite_count  retweet_count  original_author  followers_count  \
# 38   en               0             43  davideiacovozzi               18
# 39   en               0             32  davideiacovozzi               18
# 41   en               0             26  davideiacovozzi               18
# 42   en               0            213  davideiacovozzi               18
# 43   en               0            417  davideiacovozzi               18
#
#     friends_count                                           hashtags  \
# 38             55  [{'text': 'gold', 'indices': [116, 121]}, {'te...
# 39             55                                                 []
# 41             55                                                 []
# 42             55                                                 []
# 43             55                                                 []
#
#                                         user_mentions  \
# 38  [{'screen_name': 'NorthstarCharts', 'name': 'N...
# 39  [{'screen_name': 'MichaelAArouet', 'name': 'Mi...
# 41  [{'screen_name': 'goldseek', 'name': 'Peter ⚒ ...
# 42  [{'screen_name': 'charliebilello', 'name': 'Ch...
# 43  [{'screen_name': 'biancoresearch', 'name': 'Ji...
#
#                                  place
# 38                 North East  England
# 39                             Germany
# 41              Prague, Czech Republic
# 42        Join free newsletter here...
# 43  Click link below for a free trial:

# %%
cleaned_data_test.head()
# Out:
#                  created_at  \
# 0 2022-04-22 11:58:50+00:00
# 1 2022-04-22 11:55:42+00:00
# 2 2022-04-22 11:52:21+00:00
# 3 2022-04-22 11:49:03+00:00
# 4 2022-04-22 11:47:42+00:00
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="https://mobile.twitter.com" rel="nofo...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="https://mobile.twitter.com" rel="nofo...
# 4  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                        original_text  polarity  subjectivity  \
# 0  FrieslandCampina to invest US$1.6B in climate-...  0.000000      0.000000
# 1  Price hikes boost Nestlé’s sales in the first ...  0.250000      0.333333
# 2  Danone exploring all options for Russia busine...  0.000000      0.000000
# 3  Eating ultra-processed foods significantly inc...  0.375000      0.875000
# 4  Yili unveils new partnership to “upgrade” the ...  0.136364      0.454545
#
#   lang  favorite_count  retweet_count original_author  followers_count  \
# 0   en               0              0   FoodBizAfrica             1122
# 1   en               0              0   FoodBizAfrica             1122
# 2   en               0              0   FoodBizAfrica             1122
# 3   en               0              0   FoodBizAfrica             1122
# 4   en               0              0   FoodBizAfrica             1122
#
#    friends_count                                       hashtags user_mentions  \
# 0            950                                             []            []
# 1            950   [{'text': 'FoodNews', 'indices': [97, 106]}]            []
# 2            950  [{'text': 'FoodNews', 'indices': [101, 110]}]            []
# 3            950                                             []            []
# 4            950                                             []            []
#
#   place
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
cleaned_data_train.isnull().count()
# Out:
# created_at         16472
# source             16472
# original_text      16472
# polarity           16472
# subjectivity       16472
# lang               16472
# favorite_count     16472
# retweet_count      16472
# original_author    16472
# followers_count    16472
# friends_count      16472
# hashtags           16472
# user_mentions      16472
# place              16472
# dtype: int64

# %%
cleaned_data_test.isnull().count()
# Out:
# created_at         75961
# source             75961
# original_text      75961
# polarity           75961
# subjectivity       75961
# lang               75961
# favorite_count     75961
# retweet_count      75961
# original_author    75961
# followers_count    75961
# friends_count      75961
# hashtags           75961
# user_mentions      75961
# place              75961
# dtype: int64

# %% [markdown]
# There are no missing values in the datasets

# %%
cleaned_data_train.describe()
# Out:
#            polarity  subjectivity  favorite_count  retweet_count  \
# count  16472.000000  16472.000000    16472.000000   16472.000000
# mean       0.088526      0.313992        7.274951     623.669439
# std        0.279722      0.316429      529.536410    7083.382516
# min       -1.000000      0.000000        0.000000       0.000000
# 25%        0.000000      0.000000        0.000000       0.000000
# 50%        0.000000      0.288889        0.000000       2.000000
# 75%        0.200000      0.527778        0.000000      33.000000
# max        1.000000      1.000000    67814.000000  434379.000000
#
#        followers_count  friends_count
# count     1.647200e+04   16472.000000
# mean      5.327892e+04    1339.298567
# std       4.315926e+05    2970.206218
# min       0.000000e+00       0.000000
# 25%       1.120000e+02     113.000000
# 50%       5.370000e+02     433.000000
# 75%       2.131000e+03    1433.000000
# max       6.027402e+06   41866.000000

# %% [markdown]
# -The columns of significance to us are polarity and subjectivity.Polarity is whatr gives us the sentiment and it is a value that ranges from [-1,1].A value below 0 is a negative sentiment while one above zero is a positive sentiment.
# -The subjectivity column implies pulic opininion if it tends to zer and a 1 if it is a fact.

# %%
cleaned_data_test.describe()
# Out:
#            polarity  subjectivity  favorite_count  retweet_count  \
# count  75961.000000  75961.000000    75961.000000   75961.000000
# mean       0.091999      0.298064        2.425350     550.585169
# std        0.268568      0.320228       26.682133    7596.035403
# min       -1.000000      0.000000        0.000000       0.000000
# 25%        0.000000      0.000000        0.000000       0.000000
# 50%        0.000000      0.200000        0.000000       0.000000
# 75%        0.200000      0.500000        1.000000       4.000000
# max        1.000000      1.000000     2727.000000  770328.000000
#
#        followers_count  friends_count
# count     7.596100e+04   75961.000000
# mean      2.418774e+04    2430.373929
# std       1.153154e+05    7403.882073
# min       1.000000e+00       0.000000
# 25%       2.050000e+02     221.000000
# 50%       6.890000e+02     742.000000
# 75%       2.442000e+03    2168.000000
# max       3.478195e+06   89648.000000

# %%
def getAnalysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else:
        return "Positive"
    cleaned_data_train['sentiments'] = cleaned_data_train['polarity'].apply(getAnalysis)

# %%
cleaned_data_train['sentiments'] = cleaned_data_train['polarity'].apply(getAnalysis)

# %%
cleaned_data_test['sentiments'] = cleaned_data_test['polarity'].apply(getAnalysis)

# %%
cleaned_data_train.sentiments.value_counts(normalize= True)
# Out:
# Neutral     0.453254
# Positive    0.383378
# Negative    0.163368
# Name: sentiments, dtype: float64

# %%
cleaned_data_test.sentiments.value_counts(normalize= True)
# Out:
# Neutral     0.492239
# Positive    0.368136
# Negative    0.139624
# Name: sentiments, dtype: float64

# %%
cleaned_data_train.sentiments.value_counts()
# Out:
# Neutral     7466
# Positive    6315
# Negative    2691
# Name: sentiments, dtype: int64

# %%
cleaned_data_test.sentiments.value_counts()
# Out:
# Neutral     37391
# Positive    27964
# Negative    10606
# Name: sentiments, dtype: int64

# %% [markdown]
# 45% of the dataset has neutral comments
# 38% are positive
# while 16% are negative

# %%
pip install -U gensim
# Out:
# Requirement already up-to-date: gensim in c:\users\kachase\anaconda3\lib\site-packages (4.2.0)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in c:\users\kachase\anaconda3\lib\site-packages (from gensim) (5.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.0 in c:\users\kachase\anaconda3\lib\site-packages (from gensim) (1.19.5)
# Requirement already satisfied, skipping upgrade: Cython==0.29.28 in c:\users\kachase\anaconda3\lib\site-packages (from gensim) (0.29.28)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in c:\users\kachase\anaconda3\lib\site-packages (from gensim) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from gensim import corpora
import pandas as pd
import statistics
import string
from textblob import TextBlob
import sys
import tweepy
import pandas as pd
import numpy as np
import os
import nltk
import time
import seaborn as sns
import pycountry
import re
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
# !pip3 install langdetect
#from langdetect import detect
# Out:
# Requirement already satisfied: langdetect in c:\users\kachase\appdata\local\programs\python\python37\lib\site-packages (1.0.9)
# Requirement already satisfied: six in c:\users\kachase\appdata\local\programs\python\python37\lib\site-packages (from langdetect) (1.15.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\kachase\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\kachase\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\kachase\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\kachase\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\kachase\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\kachase\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\kachase\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
nltk.download('vader_lexicon')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\kachase\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kachase\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kachase\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Function to remove punctuations, links, emojis, and stop words
def preprocessTweets(tweet):
    tweet = tweet.lower()  #has to be in place
    # Remove urls
    tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE)
    # Remove user @ references and '#' from tweet
    tweet = re.sub(r'\@\w+|\#|\d+', '', tweet)
    tweet = re.sub(r'rt', '', tweet)
    # Remove stopwords
    from nltk.tokenize import word_tokenize
    tweet_tokens = word_tokenize(tweet)  # convert string to tokens
    filtered_words = [w for w in tweet_tokens if w not in stop_words]
    
    #filtered_words = [w for w in filtered_words if w in word_list]

    # Remove punctuations
    unpunctuated_words = [char for char in filtered_words if char not in string.punctuation]
    unpunctuated_words = ' '.join(unpunctuated_words)

    return "".join(unpunctuated_words)  # join words with a space in between them

# %%
# Defining my NLTK stop words and my user-defined stop words
#stop_words = list(stopwords.words('english'))
stop_words = set(STOPWORDS)
#alphabets = list(string.ascii_lowercase)
stop_words = stop_words  
#word_list = words.words()  # all words in English language
#emojis = list(UNICODE_EMO.keys())  # full list of emojis

# %%
# Apply preProcessTweets function to the 'Tweet' column to generate a new column called 'Processed Tweets'.

cleaned_data_train['clean_tweet'] = cleaned_data_train['original_text'].apply(preprocessTweets)

# %%
# Apply preProcessTweets function to the 'Tweet' column to generate a new column called 'Processed Tweets'.

cleaned_data_test['clean_tweet'] = cleaned_data_test['original_text'].apply(preprocessTweets)

# %%
cleaned_data_test.head(3)
# Out:
#                  created_at  \
# 0 2022-04-22 11:58:50+00:00
# 1 2022-04-22 11:55:42+00:00
# 2 2022-04-22 11:52:21+00:00
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="https://mobile.twitter.com" rel="nofo...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                        original_text  polarity  subjectivity  \
# 0  FrieslandCampina to invest US$1.6B in climate-...      0.00      0.000000
# 1  Price hikes boost Nestlé’s sales in the first ...      0.25      0.333333
# 2  Danone exploring all options for Russia busine...      0.00      0.000000
#
#   lang  favorite_count  retweet_count original_author  followers_count  \
# 0   en               0              0   FoodBizAfrica             1122
# 1   en               0              0   FoodBizAfrica             1122
# 2   en               0              0   FoodBizAfrica             1122
#
#    friends_count                                       hashtags user_mentions  \
# 0            950                                             []            []
# 1            950   [{'text': 'FoodNews', 'indices': [97, 106]}]            []
# 2            950  [{'text': 'FoodNews', 'indices': [101, 110]}]            []
#
#   place sentiments                                        clean_tweet
# 0   NaN    Neutral  frieslandcampina invest us .b climate-neutral ...
# 1   NaN   Positive  price hikes boost nestlé ’ s sales first three...
# 2   NaN    Neutral  danone exploring options russia business globa...

# %%
# function to return words to their base form using Lemmatizer
from nltk.tokenize import word_tokenize
def preprocessTweetsSentiments(tweet):
    tweet_tokens = word_tokenize(tweet)
    lemmatizer = WordNetLemmatizer() # instatiate an object WordNetLemmatizer Class
    lemma_words = [lemmatizer.lemmatize(w) for w in tweet_tokens]
    return " ".join(lemma_words)

# %%
# Apply preprocessTweetsSentiments function to the 'Processed Tweets' column to generate a new column
# called 'Processed_Tweets'
cleaned_data_train['Tweets_Sentiments'] = cleaned_data_train['clean_tweet'].apply(preprocessTweetsSentiments)

# %%
# Apply preprocessTweetsSentiments function to the 'Processed Tweets' column to generate a new column
# called 'Processed_Tweets'
cleaned_data_test['Tweets_Sentiments'] = cleaned_data_test['clean_tweet'].apply(preprocessTweetsSentiments)

# %%
cleaned_data_test.head(3)
# Out:
#                  created_at  \
# 0 2022-04-22 11:58:50+00:00
# 1 2022-04-22 11:55:42+00:00
# 2 2022-04-22 11:52:21+00:00
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="https://mobile.twitter.com" rel="nofo...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                        original_text  polarity  subjectivity  \
# 0  FrieslandCampina to invest US$1.6B in climate-...      0.00      0.000000
# 1  Price hikes boost Nestlé’s sales in the first ...      0.25      0.333333
# 2  Danone exploring all options for Russia busine...      0.00      0.000000
#
#   lang  favorite_count  retweet_count original_author  followers_count  \
# 0   en               0              0   FoodBizAfrica             1122
# 1   en               0              0   FoodBizAfrica             1122
# 2   en               0              0   FoodBizAfrica             1122
#
#    friends_count                                       hashtags user_mentions  \
# 0            950                                             []            []
# 1            950   [{'text': 'FoodNews', 'indices': [97, 106]}]            []
# 2            950  [{'text': 'FoodNews', 'indices': [101, 110]}]            []
#
#   place sentiments                                        clean_tweet  \
# 0   NaN    Neutral  frieslandcampina invest us .b climate-neutral ...
# 1   NaN   Positive  price hikes boost nestlé ’ s sales first three...
# 2   NaN    Neutral  danone exploring options russia business globa...
#
#                                    Tweets_Sentiments
# 0  frieslandcampina invest u .b climate-neutral i...
# 1  price hike boost nestlé ’ s sale first three m...
# 2  danone exploring option russia business global...

# %%
#  function to write results to csv
cleaned_data_train.to_csv('Tweets_Processed_train.csv',encoding='utf-8-sig', index=False) 
# Also, encoding is important when writing text to csv file

# %%
#  function to write results to csv
cleaned_data_test.to_csv('Tweets_Processed_test.csv',encoding='utf-8-sig', index=False) 
# Also, encoding is important when writing text to csv file

# %% [markdown]
# # univariate analysis on hashtags

# %%
#Method to find hashtags from tweets
def find_hashtags(tweet):
    '''This function will extract hashtags'''
    return re.findall('(#[A-Za-z]+[A-Za-z0-9-_]+)', tweet)

# %%
# update Hashtage columon with hashtages extracted from Orignal_text columon
cleaned_data_train['hashtags'] = cleaned_data_train.original_text.apply(find_hashtags)
print(cleaned_data_train['hashtags'])
# Out:
# 38       [#gold, #silver, #crypto]
# 39                              []
# 41                              []
# 42                              []
# 43                              []
#                    ...
# 24584                           []
# 24586                           []
# 24596                           []
# 24599                           []
# 24622                           []
# Name: hashtags, Length: 16472, dtype: object

# %%
# update Hashtage columon with hashtages extracted from Orignal_text columon
cleaned_data_test['hashtags'] = cleaned_data_test.original_text.apply(find_hashtags)
print(cleaned_data_test['hashtags'])
# Out:
# 0                 []
# 1        [#FoodNews]
# 2        [#FoodNews]
# 3                 []
# 4                 []
#             ...
# 92543             []
# 92544             []
# 92545             []
# 92546       [#Thuto]
# 92547             []
# Name: hashtags, Length: 75961, dtype: object

# %%
# take the rows from the hashtag columns where there are actually hashtags
hashtags_list_df_train = cleaned_data_train.loc[
                       cleaned_data_train.hashtags.apply(
                           lambda hashtags_list: hashtags_list !=[]
                       ),['hashtags']]

# %%
# take the rows from the hashtag columns where there are actually hashtags
hashtags_list_df_test = cleaned_data_test.loc[
                       cleaned_data_test.hashtags.apply(
                           lambda hashtags_list: hashtags_list !=[]
                       ),['hashtags']]

# %%
hashtags_list_df_test
# Out:
#                   hashtags
# 1              [#FoodNews]
# 2              [#FoodNews]
# 10             [#FoodNews]
# 23             [#FoodNews]
# 25             [#FoodNews]
# ...                    ...
# 92514        [#Ksazobalit]
# 92517      [#TreasureHunt]
# 92519        [#CheckOnYou]
# 92531  [#FillUpFnbStadium]
# 92546             [#Thuto]
#
# [21143 rows x 1 columns]

# %%
 #create dataframe where each use of hashtag gets its own row
flattened_hashtags_df_train = pd.DataFrame(
    [hashtag for hashtags_list in hashtags_list_df_train.hashtags
    for hashtag in hashtags_list],
    columns=['hashtag'])

# %%
 #create dataframe where each use of hashtag gets its own row
flattened_hashtags_df_test = pd.DataFrame(
    [hashtag for hashtags_list in hashtags_list_df_test.hashtags
    for hashtag in hashtags_list],
    columns=['hashtag'])

# %%
flattened_hashtags_df_test
# Out:
#                  hashtag
# 0              #FoodNews
# 1              #FoodNews
# 2              #FoodNews
# 3              #FoodNews
# 4              #FoodNews
# ...                  ...
# 42181        #Ksazobalit
# 42182      #TreasureHunt
# 42183        #CheckOnYou
# 42184  #FillUpFnbStadium
# 42185             #Thuto
#
# [42186 rows x 1 columns]

# %%
#add flatten_hashtags to tweet_df
cleaned_data_train["flattened_hashtags"]= flattened_hashtags_df_train

# %%
#add flatten_hashtags to tweet_df
cleaned_data_test["flattened_hashtags"]= flattened_hashtags_df_test

# %%
# To plot Top 20 Hashtags
cleaned_data_train['flattened_hashtags'].value_counts()[:20].plot(kind='bar')

# %%
# To plot Top 20 Hashtags
cleaned_data_test['flattened_hashtags'].value_counts()[:20].plot(kind='bar')

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words = 'english')
words = cv.fit_transform(cleaned_data_train.clean_tweet)

sum_words = words.sum(axis=0)

words_freq_train = [(word, sum_words[0, i]) for word, i in cv.vocabulary_.items()]
words_freq_train = sorted(words_freq, key = lambda x: x[1], reverse = True)

frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

frequency.head(30).plot(x='word', y='freq', kind='bar', figsize=(15, 7), color = 'blue')
plt.title("Most Frequently Occuring Words - Top 30")
# Out:
# Text(0.5, 1.0, 'Most Frequently Occuring Words - Top 30')

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words = 'english')
words = cv.fit_transform(cleaned_data_test.clean_tweet)

sum_words = words.sum(axis=0)

words_freq_test = [(word, sum_words[0, i]) for word, i in cv.vocabulary_.items()]
words_freq_test = sorted(words_freq, key = lambda x: x[1], reverse = True)

frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

frequency.head(30).plot(x='word', y='freq', kind='bar', figsize=(15, 7), color = 'blue')
plt.title("Most Frequently Occuring Words - Top 30")
# Out:
# Text(0.5, 1.0, 'Most Frequently Occuring Words - Top 30')

# %%
wordcloud = WordCloud(background_color = 'black', width = 2000, height = 1000).generate_from_frequencies(dict(words_freq_train))

plt.figure(figsize=(20,10))
plt.imshow(wordcloud)
plt.title("WordCloud - Vocabulary from all words in train set", fontsize = 22)

#normal_words =' '.join([text for text in cleaned_data['cleaned_tweet_extensive'][cleaned_data['polarity'] == 0]])
# Out:
# Text(0.5, 1.0, 'WordCloud - Vocabulary from all words in train set')

# %%
wordcloud = WordCloud(background_color = 'white', width = 2000, height = 1000).generate_from_frequencies(dict(words_freq_test))

plt.figure(figsize=(20,10))
plt.imshow(wordcloud)
plt.title("WordCloud - Vocabulary from all words in test set", fontsize = 22)

#normal_words =' '.join([text for text in cleaned_data['cleaned_tweet_extensive'][cleaned_data['polarity'] == 0]])
# Out:
# Text(0.5, 1.0, 'WordCloud - Vocabulary from all words in test set')

# %%
normal_words =' '.join([text for text in cleaned_data_train['clean_tweet'][cleaned_data_train['polarity'] == 0]])
wordcloud = WordCloud(width=2000, height=1000, random_state = 0).generate(normal_words)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('The Neutral Words in train set')
plt.show()

# %%
normal_words =' '.join([text for text in cleaned_data_test['clean_tweet'][cleaned_data_test['polarity'] == 0]])
wordcloud = WordCloud(background_color = 'white',width=2000, height=1000, random_state = 0).generate(normal_words)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('The Neutral Wordsin test set')
plt.show()

# %%
negative_words =' '.join([text for text in cleaned_data_train['clean_tweet'][cleaned_data_train['polarity'] == 1]])

wordcloud = WordCloud(background_color = 'black', width=2000, height=1000, random_state = 0).generate(negative_words)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('The Negative Words in train set')
plt.show()

# %%
negative_words =' '.join([text for text in cleaned_data_test['clean_tweet'][cleaned_data_test['polarity'] == 1]])

wordcloud = WordCloud(background_color = 'white', width=2000, height=1000, random_state = 0).generate(negative_words)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('The Negative Words in test set')
plt.show()

# %%
# function to collect hashtags
def mention_extract(original_text):
    mentions = []
    # Loop over the words in the tweet
    for text in original_text:
        ht = re.findall(r"@(\w+)",text)
        mentions.append(ht)

    return mentions

def generate_mentions_freqdist(mentions):
    a = nltk.FreqDist(mentions)
    d = pd.DataFrame({'Mentions': list(a.keys()),
                      'Count': list(a.values())})
    # selecting top 15 most frequent hashtags     
    d = d.nlargest(columns="Count", n = 25)
    plt.figure(figsize=(16,7))
    ax = sns.barplot(data=d, x= "Mentions", y = "Count")
    plt.xticks(rotation=80)
    ax.set(ylabel = 'Count')
    #plt.savefig(text_query + '_hashtag_frequency_dist.png')
    plt.show()

# %%
mentions = mention_extract(cleaned_data_train['original_text'])
mentions = sum(mentions, [])

generate_mentions_freqdist(mentions)

# %%
mentions = mention_extract(cleaned_data_test['original_text'])
mentions = sum(mentions, [])

generate_mentions_freqdist(mentions)

# %%
train_df=pd.read_csv('Tweets_Processed_train.csv')

# %%
test_df=pd.read_csv('Tweets_Processed_test.csv')

# %%
# Create dataframe for Count of Sentiment Categories
bar_chart_train = train_df['sentiments'].value_counts().rename_axis('Sentiment').to_frame('Total Tweets').reset_index()

# %%
# Create dataframe for Count of Sentiment Categories
bar_chart_test = test_df['sentiments'].value_counts().rename_axis('Sentiment').to_frame('Total Tweets').reset_index()

# %%
import plotly.express as px
sentiments_barchart_train = px.bar(bar_chart_train, x = 'Sentiment', y='Total Tweets', color='Sentiment')

sentiments_barchart_train.update_layout(title='Distribution of Sentiments Results',
                                  margin={"r": 0, "t": 30, "l": 0, "b": 0})

sentiments_barchart_train.show() #Display plot. 

# I used renderer so that the plots show on the web when people view my notebook. 
# For interactive plots, exclude the "renderer" argument
# Note, I further customized the plot on Chart Studio for my Medium post
# Out:
# <div>                            <div id="3d916442-52b5-4c3b-b467-257a3125e142" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d916442-52b5-4c3b-b467-257a3125e142")) {                    Plotly.newPlot(                        "3d916442-52b5-4c3b-b467-257a3125e142",                        [{"alignmentgroup":"True","hovertemplate":"Sentiment=%{x}<br>Total Tweets=%{y}<extra></extra>","legendgroup":"Neutral","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Neutral","offsetgroup":"Neutral","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Neutral"],"xaxis":"x","y":[7466],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Sentiment=%{x}<br>Total Tweets=%{y}<extra></extra>","legendgroup":"Positive","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Positive"],"xaxis":"x","y":[6315],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Sentiment=%{x}<br>Total Tweets=%{y}<extra></extra>","legendgroup":"Negative","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Negative"],"xaxis":"x","y":[2691],"yaxis":"y"}],                        {"barmode":"relative","legend":{"title":{"text":"Sentiment"},"tracegroupgap":0},"margin":{"b":0,"l":0,"r":0,"t":30},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888 ...

# %%
import plotly.express as px
sentiments_barchart_test = px.bar(bar_chart_test, x = 'Sentiment', y='Total Tweets', color='Sentiment')

sentiments_barchart_test.update_layout(title='Distribution of Sentiments Results',
                                  margin={"r": 0, "t": 30, "l": 0, "b": 0})

sentiments_barchart_test.show() #Display plot. 

# I used renderer so that the plots show on the web when people view my notebook. 
# For interactive plots, exclude the "renderer" argument
# Note, I further customized the plot on Chart Studio for my Medium post
# Out:
# <div>                            <div id="1123c29c-06fa-4be5-be64-3653ae1b4eab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1123c29c-06fa-4be5-be64-3653ae1b4eab")) {                    Plotly.newPlot(                        "1123c29c-06fa-4be5-be64-3653ae1b4eab",                        [{"alignmentgroup":"True","hovertemplate":"Sentiment=%{x}<br>Total Tweets=%{y}<extra></extra>","legendgroup":"Neutral","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Neutral","offsetgroup":"Neutral","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Neutral"],"xaxis":"x","y":[37391],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Sentiment=%{x}<br>Total Tweets=%{y}<extra></extra>","legendgroup":"Positive","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Positive"],"xaxis":"x","y":[27964],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Sentiment=%{x}<br>Total Tweets=%{y}<extra></extra>","legendgroup":"Negative","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Negative"],"xaxis":"x","y":[10606],"yaxis":"y"}],                        {"barmode":"relative","legend":{"title":{"text":"Sentiment"},"tracegroupgap":0},"margin":{"b":0,"l":0,"r":0,"t":30},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88 ...

# %%
train_df.groupby('sentiments').describe()
# Out:
#            polarity                                                        \
#               count      mean       std           min       25%       50%
# sentiments
# Negative     2691.0 -0.261099  0.230304 -1.000000e+00 -0.375000 -0.178571
# Neutral      7466.0  0.000000  0.000000  0.000000e+00  0.000000  0.000000
# Positive     6315.0  0.342172  0.236230  3.700743e-17  0.150758  0.285714
#
#                               subjectivity            ... followers_count  \
#             75%           max        count      mean  ...             75%
# sentiments                                            ...
# Negative   -0.1 -9.251859e-18       2691.0  0.498299  ...          2270.0
# Neutral     0.0  0.000000e+00       7466.0  0.070872  ...          1953.0
# Positive    0.5  1.000000e+00       6315.0  0.522885  ...          1953.0
#
#                       friends_count                                        \
#                   max         count         mean          std  min    25%
# sentiments
# Negative    6027402.0        2691.0  1457.821628  3300.106743  0.0  132.0
# Neutral     6027402.0        7466.0  1321.967051  3039.117464  0.0  101.0
# Positive    6027402.0        6315.0  1309.282977  2728.879703  0.0  113.0
#
#
#               50%     75%      max
# sentiments
# Negative    472.0  1594.0  41866.0
# Neutral     413.0  1404.0  41866.0
# Positive    445.0  1358.0  41866.0
#
# [3 rows x 48 columns]

# %%
test_df.groupby('sentiments').describe()
# Out:
#            polarity                                                     \
#               count      mean       std           min    25%  50%  75%
# sentiments
# Negative    10606.0 -0.255882  0.213170 -1.000000e+00 -0.375 -0.2 -0.1
# Neutral     37391.0  0.000000  0.000000  0.000000e+00  0.000  0.0  0.0
# Positive    27964.0  0.346955  0.237646  3.469447e-18  0.150  0.3  0.5
#
#                          subjectivity            ... followers_count  \
#                      max        count      mean  ...             75%
# sentiments                                       ...
# Negative   -6.938894e-18      10606.0  0.489559  ...          2213.0
# Neutral     0.000000e+00      37391.0  0.070156  ...          2442.0
# Positive    1.000000e+00      27964.0  0.530175  ...          2442.0
#
#                       friends_count                                         \
#                   max         count         mean           std  min    25%
# sentiments
# Negative    3478194.0       10606.0  3032.815010  10400.912263  0.0  221.0
# Neutral     3478195.0       37391.0  2382.843759   7185.689921  0.0  224.0
# Positive    3478195.0       27964.0  2265.437241   6218.729975  0.0  215.0
#
#
#               50%     75%      max
# sentiments
# Negative    735.0  2173.0  89648.0
# Neutral     742.0  2173.0  89648.0
# Positive    742.0  2147.0  89648.0
#
# [3 rows x 48 columns]

# %% [markdown]
# Dropping the rows with neutral polarity

# %%
to_drop_train=train_df[train_df['polarity'] == 0 ].index
train_df.drop(to_drop , inplace=True)

# %%
to_drop_test=test_df[test_df['polarity'] == 0 ].index
test_df.drop(to_drop , inplace=True)

# %%
train_df.shape
# Out:
# (9006, 16)

# %%
test_df.shape
# Out:
# (68495, 17)

# %%
# To count the iterations 
from tqdm import tqdm
# creating the document corpus
corpus_train = []   
for index, row in tqdm(train_df.iterrows()):
    tweet = preprocessTweets(row['original_text'])
    corpus_train.append(tweet)
# Out:
# 9006it [00:15, 576.28it/s]

# %%
# To count the iterations 
from tqdm import tqdm
# creating the document corpus
corpus_test = []   
for index, row in tqdm(test_df.iterrows()):
    tweet = preprocessTweets(row['original_text'])
    corpus_test.append(tweet)
# Out:
# 68495it [00:42, 1625.49it/s]

# %%
score_series = train_df['sentoment'].map({'positive': 1, 'negative': 0})
text_series = train_df['clean_text']
X = text_series.tolist()
y = score_series.tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'score'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-186-a9361ba86011> in <module>
# ----> 1 score_series = train_df['score'].map({'positive': 1, 'negative': 0})
#       2 text_series = train_df['clean_text']
#       3 X = text_series.tolist()
#       4 y = score_series.tolist()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'score'

# %%
# creating bag of words

from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features = 2500)
x = cv.fit_transform(corpus_train).toarray()
y = processed_data.iloc[:, -3]

print(x.shape)
print(y.head(5))
# Out:
# (9006, 2500)
# 0    Positive
# 1    Positive
# 4    Negative
# 5    Negative
# 6    Positive
# Name: sentiments, dtype: object

# %%
# creating bag of words

from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features = 2500)
x_test = cv.fit_transform(corpus_test).toarray()


print(x.shape)
# Out:
# (9006, 2500)

# %%
# splitting the training data into train and valid sets

from sklearn.model_selection import train_test_split

x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size = 0.25, random_state = 42)

print(x_train.shape)
print(x_valid.shape)
print(y_train.shape)
print(y_valid.shape)
# Out:
# (6754, 2500)
# (2252, 2500)
# (6754,)
# (2252,)

# %%
# standardization

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_valid = sc.transform(x_valid)
x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

model = RandomForestClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_valid)

print("Training Accuracy :", model.score(x_train, y_train))
print("Validation Accuracy :", model.score(x_valid, y_valid))

# calculating the f1 score for the validation set
print("F1 score :", f1_score(y_valid, y_pred))

# confusion matrix
cm = confusion_matrix(y_valid, y_pred)
print(cm)
# Out:
# Training Accuracy : 0.9872668048563814
# Validation Accuracy : 0.8325932504440497
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-179-3518613cf11d> in <module>
#      12
#      13 # calculating the f1 score for the validation set
# ---> 14 print("F1 score :", f1_score(y_valid, y_pred))
#      15
#      16 # confusion matrix
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight)
#     718     return fbeta_score(y_true, y_pred, 1, labels=labels,
#     719                        pos_label=pos_label, average=average,
# --> 720                        sample_weight=sample_weight)
#     721
#     722
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight)
#     832                                                  average=average,
#     833                                                  warn_for=('f-score',),
# --> 834                                                  sample_weight=sample_weight)
#     835     return f
#     836
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight)
#    1041                 else:
#    1042                     raise ValueError("pos_label=%r is not a valid label: %r" %
# -> 1043                                      (pos_label, present_labels))
#    1044             labels = [pos_label]
#    1045         else:
#
# ValueError: pos_label=1 is not a valid label: array(['Negative', 'Positive'], dtype='<U8')

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_valid)

print("Training Accuracy :", model.score(x_train, y_train))
print("Validation Accuracy :", model.score(x_valid, y_valid))

# calculating the f1 score for the validation set
print("f1 score :", f1_score(y_valid, y_pred))

# confusion matrix
cm = confusion_matrix(y_valid, y_pred)
print(cm)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_valid)

print("Training Accuracy :", model.score(x_train, y_train))
print("Validation Accuracy :", model.score(x_valid, y_valid))

# calculating the f1 score for the validation set
print("f1 score :", f1_score(y_valid, y_pred))

# confusion matrix
cm = confusion_matrix(y_valid, y_pred)
print(cm)

# %%
from sklearn.svm import SVC

model = SVC()
model.fit(x_train, y_train)

y_pred = model.predict(x_valid)

print("Training Accuracy :", model.score(x_train, y_train))
print("Validation Accuracy :", model.score(x_valid, y_valid))

# calculating the f1 score for the validation set
print("f1 score :", f1_score(y_valid, y_pred))

# confusion matrix
cm = confusion_matrix(y_valid, y_pred)
print(cm)

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_valid)

print("Training Accuracy :", model.score(x_train, y_train))
print("Validation Accuracy :", model.score(x_valid, y_valid))

# calculating the f1 score for the validation set
print("f1 score :", f1_score(y_valid, y_pred))

# confusion matrix
cm = confusion_matrix(y_valid, y_pred)
print(cm)
